# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshawaskar45-jpg/AI-ML-Assignment-/blob/main/Dfs_recursive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Graph represented as an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# %%
def dfs_recursive(graph, current, goal, visited=None, path=None):
    if visited is None:
        visited = set()

    if path is None:
        path = []

    visited.add(current)
    path.append(current)

    # Goal found
    if current == goal:
        return path

    # Visit neighbors recursively
    for neighbor in graph[current]:
        if neighbor not in visited:
            result = dfs_recursive(graph, neighbor, goal, visited, path.copy())
            if result:
                return result

    return None

# %%
# Example
start = 'A'
goal = 'F'

result = dfs_recursive(graph, start, goal)

if result:
    print("Path found:", " -> ".join(result))
else:
    print("No path found")
# Out:
# Path found: A -> B -> E -> F
